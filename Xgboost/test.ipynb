# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
import os
import pandas as pd
dataset_dir = r'D:\M143020071\MI\xgboost_results\ECG_Founder_feature\sr500_0.5_50_MI_win10s_step2s_ECG_signal\sr500_0.5-50_ecg_2-7min_10win2stride_trH146P146win_teH146P146win_1024ecgfounder_split/'

train_id, test_id = [], []
for fold in range(5):
    train = pd.read_csv(os.path.join(dataset_dir, f'y_train_label_{fold+1}.csv'))
    test = pd.read_csv(os.path.join(dataset_dir, f'y_test_label_{fold+1}.csv'))
    train_id.append(np.unique(train['research_id'].values))
    test_id.append(np.unique(test['research_id'].values))

# %%
test_id[4]
# Out:
# array([  2,  10,  22,  24,  48,  87, 103, 119, 124, 157, 159, 160, 167,
#        178, 209, 210, 216, 219, 221, 233, 268, 269, 291, 295, 299, 300,
#        303, 308, 336, 342, 344, 366, 369, 371, 375, 378, 410, 412, 415,
#        417, 445, 446, 449, 451, 453, 455, 499, 508, 512, 528, 543, 552,
#        562, 578, 605, 606, 608, 611, 626, 656, 661, 671, 692, 702, 736,
#        739, 740, 768, 769, 793, 802, 809, 810, 823, 839, 842, 866, 894,
#        899, 910])

# %%
# DATA_DIR = r"D:\M143020071\MI\xgboost_results\iSKNA_signal\ch1\sr10000_500_3000_MI_1000pts_win20s_step2s\mantisPCA_test\Mantis transform\X_raw_transformed_0.npy"
# X_raw = np.load(DATA_DIR)
# print(X_raw)
# Out:
# [[-0.18906689  0.16969585  0.08981314 ...  0.02459784  0.57783353
#    0.01593424]
#  [-0.20188622  0.1680418   0.08556097 ...  0.02527294  0.5486367
#   -0.00320039]
#  [-0.2047708   0.17181362  0.08325703 ...  0.01436859  0.53305984
#   -0.00527207]
#  ...
#  [-0.19073485  0.167162    0.09297348 ...  0.02971769  0.58985883
#    0.00117505]
#  [-0.19140062  0.16688958  0.09166633 ...  0.02681508  0.5931401
#    0.00282881]
#  [-0.18759857  0.16866763  0.09352278 ...  0.03119507  0.5994076
#    0.00566185]]
